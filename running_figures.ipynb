# %% [markdown]
# ### This Code is specifically for generating Figures

# %%
from vf_popul_model import VF_Population_Model
from single_unit_plots import run_same_plot

# %% [markdown]
# ### Generating Figure 1
# Shows the Single Unit Models

# %%
run_same_plot("SA", "out", 1)
# Out:
# WARNING:root:File not found for 3.61 and out
# WARNING:root:File not found for 4.08 and out
# WARNING:root:File not found for 4.17 and out
# WARNING:root:File not found for 4.31 and out
# WARNING:root:File not found for 4.56 and out
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
